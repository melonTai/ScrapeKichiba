# %%
import pandas as pd

# %%
url = r"http://www.kichiuma.net/php/search.php?race_id=202201090776&date=2022%2F1%2F9&no=7&id=76&p=sp"

# %%
dfs = pd.read_html(url, match="枠")

# %%
dfs
# Out:
# [    枠   馬    競 走 馬 名 SP調整        SP平均        SP最大         \
#      枠   馬    競 走 馬 名 SP調整 SP調整.1 SP平均 SP平均.1 SP最大 SP最大.1
#  0   1   1  コングールテソーロ    ◎     83    ◎     86    ▲     87
#  1   1   2     ネオトゥルー    ○     82    ○     84    ◎     92
#  2   2   3    ユキノヴェルデ    …     72    …     73    …     78
#  3   2   4  ホウオウエンジェル    …     71    …     72    …     81
#  4   3   5  ポップアップスター    △     78    ▲     84    ○     89
#  5   3   6      アイスマン    …     71    …     76    …     78
#  6   4   7    ノボベルサイユ    △     78    …     76    …     79
#  7   4   8  シーオブドリームス    …     76    …     76    …     78
#  8   5   9      ロレンツォ    …     78    …     70    …     80
#  9   5  10      エンピレオ    …     77    …     74    …     75
#  10  6  11   イサチルプリンス    △     79    …     77    …     81
#  11  6  12  トミケンカラバティ    …     78    △     81    △     84
#  12  7  13    アイアンゾーン    …     78    △     78    △     83
#  13  7  14    レイデルマール    ▲     81    △     79    △     83
#  14  8  15  キャンディキューブ    …     69    …     71    …     77
#  15  8  16  ビゾンテノブファロ    …     69    …     72    …     78
#
#     ※スピード指数履歴欄の詳細【1行目】⇒競馬場、距離【2行1列目】⇒スピード指数、【2行2列目上段】⇒前半スピード(先行)指数、【2行2列目下段】⇒後半3Fスピード(上がり)指数(注)中央競馬、海外競馬、ばんえい競馬のスピード指数履歴はございません。  \
#                                                                                                                               前走
#  0                                   中山1200稍  87  3  7
#  1                                  東京1300良  86  -1  9
#  2                                  新潟1200良  70  -8  2
#  3                                  札幌1200良  71  0  -5
#  4                                東京1400良  82  -10  14
#  5                                                 NaN
#  6                                  中京1200重  76  8  -6
#  7                                  中山1200良  74  2  -9
#  8                                  中京1600稍  80  8  -3
#  9                                新潟1200良  75  10  -10
#  10                                 東京1400良  81  6  -4
#  11                                  中京1200重  80  4  3
#  12                                 中山1200稍  78  -8  5
#  13                                  中京1200重  83  6  5
#  14                                新潟1200良  67  2  -12
#  15                                新潟1200良  67  -5  -5
#
#                                                                        \
#                       前々走                   3走前                   4走前
#  0     東京1400良  84  -0  4   東京1400良  84  -7  13     東京1400良  87  5  2
#  1      東京1300良  92  6  8     東京1300良  90  5  7    東京1400良  82  -0  3
#  2   新潟1200不  71  14  -18  中山1200良  78  -14  12   小倉1700良  69  -2  -1
#  3      札幌1200良  81  8  0   函館1200良  76  10  -8  函館1200良  73  11  -13
#  4      東京1300良  89  6  5   中山1200良  87  -2  12  東京1400良  82  -10  14
#  5    中山1200稍  73  -12  2    東京1400良  76  -6  2    中山1200不  78  0  -3
#  6     福島1150良  72  -9  6    中山1200稍  79  -7  6  中山1200良  77  12  -16
#  7     新潟1200稍  78  7  -2  東京1400重  78  18  -20    東京1400良  78  2  -4
#  8   中山1800良  59  -11  -6                   NaN                   NaN
#  9   東京1400良  75  12  -17  東京1600良  72  15  -23                   NaN
#  10   中山1200不  78  -10  8   新潟1400良  73  -0  -1    東京1400良  80  -6  7
#  11   福島1150良  82  -4  16    東京1400良  80  2  -1     東京1400良  84  2  2
#  12     中山1200良  83  4  0    新潟1000良  75  -3  3    新潟1200良  74  -4  3
#  13    中京1400良  74  2  -2                   NaN                   NaN
#  14    新潟1200良  73  5  -7   福島1150稍  70  9  -15  東京1400稍  70  17  -28
#  15    東京1600良  78  5  -7   中山1600良  73  -0  -5   中山1800重  71  7  -15
#
#
#                       5走前
#  0      中山1200良  86  6  1
#  1   中京1400良  72  10  -13
#  2     東京1400重  76  2  -6
#  3   東京1400良  59  19  -42
#  4   中山1200良  82  -12  16
#  5     中山1200良  76  0  -5
#  6     東京1400良  77  6  -9
#  7    中京1400良  70  5  -10
#  8                    NaN
#  9                    NaN
#  10   中山1200稍  75  -2  -3
#  11     函館1000良  80  0  8
#  12  東京1400稍  78  19  -21
#  13                   NaN
#  14   中山1200良  77  -3  -0
#  15   中山1600良  73  -1  -5  ]

# %%
spdf = dfs[0]

# %%
spdf
# Out:
#     枠   馬    競 走 馬 名 SP調整        SP平均        SP最大         \
#     枠   馬    競 走 馬 名 SP調整 SP調整.1 SP平均 SP平均.1 SP最大 SP最大.1
# 0   1   1  コングールテソーロ    ◎     83    ◎     86    ▲     87
# 1   1   2     ネオトゥルー    ○     82    ○     84    ◎     92
# 2   2   3    ユキノヴェルデ    …     72    …     73    …     78
# 3   2   4  ホウオウエンジェル    …     71    …     72    …     81
# 4   3   5  ポップアップスター    △     78    ▲     84    ○     89
# 5   3   6      アイスマン    …     71    …     76    …     78
# 6   4   7    ノボベルサイユ    △     78    …     76    …     79
# 7   4   8  シーオブドリームス    …     76    …     76    …     78
# 8   5   9      ロレンツォ    …     78    …     70    …     80
# 9   5  10      エンピレオ    …     77    …     74    …     75
# 10  6  11   イサチルプリンス    △     79    …     77    …     81
# 11  6  12  トミケンカラバティ    …     78    △     81    △     84
# 12  7  13    アイアンゾーン    …     78    △     78    △     83
# 13  7  14    レイデルマール    ▲     81    △     79    △     83
# 14  8  15  キャンディキューブ    …     69    …     71    …     77
# 15  8  16  ビゾンテノブファロ    …     69    …     72    …     78
#
#    ※スピード指数履歴欄の詳細【1行目】⇒競馬場、距離【2行1列目】⇒スピード指数、【2行2列目上段】⇒前半スピード(先行)指数、【2行2列目下段】⇒後半3Fスピード(上がり)指数(注)中央競馬、海外競馬、ばんえい競馬のスピード指数履歴はございません。  \
#                                                                                                                              前走
# 0                                   中山1200稍  87  3  7
# 1                                  東京1300良  86  -1  9
# 2                                  新潟1200良  70  -8  2
# 3                                  札幌1200良  71  0  -5
# 4                                東京1400良  82  -10  14
# 5                                                 NaN
# 6                                  中京1200重  76  8  -6
# 7                                  中山1200良  74  2  -9
# 8                                  中京1600稍  80  8  -3
# 9                                新潟1200良  75  10  -10
# 10                                 東京1400良  81  6  -4
# 11                                  中京1200重  80  4  3
# 12                                 中山1200稍  78  -8  5
# 13                                  中京1200重  83  6  5
# 14                                新潟1200良  67  2  -12
# 15                                新潟1200良  67  -5  -5
#
#                                                                       \
#                      前々走                   3走前                   4走前
# 0     東京1400良  84  -0  4   東京1400良  84  -7  13     東京1400良  87  5  2
# 1      東京1300良  92  6  8     東京1300良  90  5  7    東京1400良  82  -0  3
# 2   新潟1200不  71  14  -18  中山1200良  78  -14  12   小倉1700良  69  -2  -1
# 3      札幌1200良  81  8  0   函館1200良  76  10  -8  函館1200良  73  11  -13
# 4      東京1300良  89  6  5   中山1200良  87  -2  12  東京1400良  82  -10  14
# 5    中山1200稍  73  -12  2    東京1400良  76  -6  2    中山1200不  78  0  -3
# 6     福島1150良  72  -9  6    中山1200稍  79  -7  6  中山1200良  77  12  -16
# 7     新潟1200稍  78  7  -2  東京1400重  78  18  -20    東京1400良  78  2  -4
# 8   中山1800良  59  -11  -6                   NaN                   NaN
# 9   東京1400良  75  12  -17  東京1600良  72  15  -23                   NaN
# 10   中山1200不  78  -10  8   新潟1400良  73  -0  -1    東京1400良  80  -6  7
# 11   福島1150良  82  -4  16    東京1400良  80  2  -1     東京1400良  84  2  2
# 12     中山1200良  83  4  0    新潟1000良  75  -3  3    新潟1200良  74  -4  3
# 13    中京1400良  74  2  -2                   NaN                   NaN
# 14    新潟1200良  73  5  -7   福島1150稍  70  9  -15  東京1400稍  70  17  -28
# 15    東京1600良  78  5  -7   中山1600良  73  -0  -5   中山1800重  71  7  -15
#
#
#                      5走前
# 0      中山1200良  86  6  1
# 1   中京1400良  72  10  -13
# 2     東京1400重  76  2  -6
# 3   東京1400良  59  19  -42
# 4   中山1200良  82  -12  16
# 5     中山1200良  76  0  -5
# 6     東京1400良  77  6  -9
# 7    中京1400良  70  5  -10
# 8                    NaN
# 9                    NaN
# 10   中山1200稍  75  -2  -3
# 11     函館1000良  80  0  8
# 12  東京1400稍  78  19  -21
# 13                   NaN
# 14   中山1200良  77  -3  -0
# 15   中山1600良  73  -1  -5

# %%
dfs = pd.read_html(url, match="本賞金")

# %%
info_df = dfs[0]

# %%
info_df
# Out:
#        0                                    1  \
# 0  中山  7          2022年01月09日　(日曜日)　中山競馬　第7競走
# 1  中山  7                    4歳上1勝クラス(500万円以下)
# 2  中山  7  1回中山3日目サラ系４歳以上１勝クラス定量16頭　ダ1200m　右回り
#
#                                            2
# 0  本賞金(万円)(1着)770(2着)310(3着)190(4着)120(5着)77
# 1  本賞金(万円)(1着)770(2着)310(3着)190(4着)120(5着)77
# 2                                   発走 13:15

# %%
import traceback
try:
    dfs = pd.read_html(url, match="枠")
    df = dfs[0]
except ValueError as e:
    message = "".join(traceback.format_exception_only(type(e), e))
    if "No tables found matching pattern" in message:
        print("none")
    else:
        raise ValueError(e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8220/1488169607.py in <module>
#       2 try:
# ----> 3     dfs = pd.read_html(url, match="あいうえお")
#       4     df = dfs[0]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     925         assert retained is not None  # for mypy
# --> 926         raise retained
#     927
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\html.py in parse_tables(self)
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\html.py in _parse_tables(self, doc, match, attrs)
#     567         if not result:
# --> 568             raise ValueError(f"No tables found matching pattern {repr(match.pattern)}")
#     569         return result
#
# ValueError: No tables found matching pattern 'あいうえお'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8220/1488169607.py in <module>
#       5 except ValueError as e:
#       6     message = "".join(traceback.format_exception_only(type(e), e))
# ----> 7     raise ValueError(e)
#       8     if "No tables found matching pattern" in message:
#       9         print("none")
#
# ValueError: No tables found matching pattern 'あいうえお'
